# %%
import sys
sys.path.append("../src/")   

from data_preprocessing import (
    load_dataset,
    build_graph,
    preprocess_graph,
    save_graph,
)

# %%
# Load Facebook dataset
edges = load_dataset("../data/raw/twitter_combined.txt")
edges.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Load Facebook dataset
# ----> 2 edges = load_dataset("../data/raw/twitter_combined.txt")
#       3 edges.head()
#
# NameError: name 'load_dataset' is not defined

# %%
G = build_graph(edges)
G_cleaned = preprocess_graph(G)
# Out:
# Graph created with 4039 nodes and 88234 edges
# After preprocessing: 4039 nodes, 88234 edges

# %%
save_graph(G_cleaned, "../data/processed/facebook_cleaned.edgelist")
# Out:
# Graph saved to ../data/processed/facebook_cleaned.edgelist

# %%
import matplotlib.pyplot as plt
import networkx as nx

plt.figure(figsize=(6,6))
nx.draw(G_cleaned, node_size=20, alpha=0.6, edge_color="gray")
plt.show()
